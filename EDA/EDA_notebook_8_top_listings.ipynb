# %% [markdown]
# # This notebook will serve for the analysis of the Room Features for the TFW project

# %%
# Import necassary libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

ROOT = os.environ.get('PWD')

# %%
# read in dataset

df_room_features = pd.read_csv('../data/rooms_features_20210713.csv', low_memory=False)

# %%
df_room_features.head(30)
# Out:
#                               listing_id  description area  \
# 0   fbd74bce-23dd-53e7-b988-8beb85160d6f      balcony  NaN
# 1   fbd74bce-23dd-53e7-b988-8beb85160d6f     bathroom  NaN
# 2   fbd74bce-23dd-53e7-b988-8beb85160d6f     bathroom  NaN
# 3   fbd74bce-23dd-53e7-b988-8beb85160d6f     bathroom  NaN
# 4   fbd74bce-23dd-53e7-b988-8beb85160d6f     bathroom  NaN
# 5   fbd74bce-23dd-53e7-b988-8beb85160d6f      bedroom  NaN
# 6   fbd74bce-23dd-53e7-b988-8beb85160d6f      bedroom  NaN
# 7   fbd74bce-23dd-53e7-b988-8beb85160d6f      bedroom  NaN
# 8   fbd74bce-23dd-53e7-b988-8beb85160d6f     category  NaN
# 9   fbd74bce-23dd-53e7-b988-8beb85160d6f      general  NaN
# 10  fbd74bce-23dd-53e7-b988-8beb85160d6f      general  NaN
# 11  fbd74bce-23dd-53e7-b988-8beb85160d6f      general  NaN
# 12  fbd74bce-23dd-53e7-b988-8beb85160d6f      kitchen  NaN
# 13  fbd74bce-23dd-53e7-b988-8beb85160d6f      kitchen  NaN
# 14  fbd74bce-23dd-53e7-b988-8beb85160d6f      kitchen  NaN
# 15  fbd74bce-23dd-53e7-b988-8beb85160d6f      kitchen  NaN
# 16  fbd74bce-23dd-53e7-b988-8beb85160d6f      kitchen  NaN
# 17  fbd74bce-23dd-53e7-b988-8beb85160d6f      kitchen  NaN
# 18  fbd74bce-23dd-53e7-b988-8beb85160d6f      kitchen  NaN
# 19  fbd74bce-23dd-53e7-b988-8beb85160d6f      kitchen  NaN
# 20  fbd74bce-23dd-53e7-b988-8beb85160d6f      kitchen  NaN
# 21  fbd74bce-23dd-53e7-b988-8beb85160d6f  living room  NaN
# 22  fbd74bce-23dd-53e7-b988-8beb85160d6f  living room  NaN
# 23  fbd74bce-23dd-53e7-b988-8beb85160d6f  living room  NaN
# 24  fbd74bce-23dd-53e7-b988-8beb85160d6f  living room  NaN
# 25  fbd74bce-23dd-53e7-b988-8beb85160d6f     washroom  NaN
# 26  fbd74bce-23dd-53e7-b988-8beb85160d6f     washroom  NaN
# 27  b766fc7c-6d44-5c86-b6d1-3f699c78b3a6      balcony    0
# 28  b766fc7c-6d44-5c86-b6d1-3f699c78b3a6     bathroom  NaN
# 29  b766fc7c-6d44-5c86-b6d1-3f699c78b3a6     bathroom  NaN
#
#           description.1
# 0      garden furniture
# 1                mirror
# 2                shower
# 3                toilet
# 4            wash basin
# 5            double bed
# 6            single bed
# 7              wardrobe
# 8                   NaN
# 9       central heating
# 10            hot water
# 11      private parking
# 12       coffee machine
# 13           dishwasher
# 14           egg cooker
# 15  freezer compartment
# 16          kitchenette
# 17            microwave
# 18                 oven
# 19         refrigerator
# 20              toaster
# 21             armchair
# 22           digital TV
# 23                radio
# 24                 sofa
# 25                dryer
# 26      washing machine
# 27     garden furniture
# 28           hair dryer
# 29               mirror

# %%
df_room_features.area.unique()
# Out:
# array([nan, '0', '6', '13', '4', '10', '17', '12', '14', '20', '2', '15',
#        '7', '25', '8', '50', '9', '5', '100', '200', '500', '180', '30',
#        '175', '18', '16', '3', '400', '19', '10000', '60', '450', '28',
#        '40', '45', '1000', '2000', '70', '3000', '24', '35', '7400', '1',
#        '53', '42', '11', '36', '22', '900', '75', '32', '29', '23', '600',
#        '700', '80', '150', '120', '800', '2200', '27', '950', '185',
#        '1600', '38', '33', '4000', '160', '33000', '2300', '47', '300',
#        '1100', '1500', '2500', '31', '52', '1300', '26', '1200', '350',
#        '5000', '90', '190', '280', '750', '44', '21', '1800', '250',
#        '25000', '130', '34', '140', '240', '1400', '65', '56', '48',
#        '112', '55', '3500', '50  - 60', '20000', '670', '1700', '10-25',
#        '2100', '230', '39', '43', '7000', '170', '850', '58', '027', '49',
#        '8500', '64', '15000', '2400', '18-25', '37', '68', '4 - 5',
#        '22 - 23', '1660', '110', '550', '89', '2600', '85', '84', '77',
#        '50-80', '51', '54', '664', '66', '12 - 25', '6000', '59', '13000',
#        '325', '95', '560', '8000', '78', '72', '41', '508', '74', '57',
#        '707', '2900', '444', '12-40', '2800', '650', '3800', '320',
#        '6500', '360', '380', '640', '71', '580', '630', '805', '1250',
#        '680', '12000', '509', '234', '665', '210', '620', '530', '770',
#        '10-15', '12-20', '15-20', '70000', '12-15', '13-16', '1150',
#        '514', '61', '96', '980', '1050', '705', '10-12', '30 - 40', '46',
#        '1224', '780', '6400', '598', '236', '540', '370', '12-18', '814',
#        '220', '18000', '125', '480', '7-8', '6299', '884', '260', '173',
#        '858', '4400', '690', '296', '17000', '3-4', '132', '151', '275',
#        '615', '76', '460', '82', '710', '30000', '8-12', '88', '390',
#        '40000', '4525', '8300', '114', '115', '67', '08', '860', '520',
#        '930', '60000', '81', '27-38', '135', '165', '63', '310', '62',
#        '12800', '91', '1770', '730', '5-6', '844', '50000', '4500', '105',
#        '98', '3200', '960', '155', '405', '24000', '6-10', '1900', '760',
#        '1345', '725', '14 - 16', '92', '590', '12 - 15', '830', '3300',
#        '870', '7-12', '12 - 16', '15 - 18', '20 - 30', '420', '4600',
#        '498', '505', '13 - 14', '312', '1084', '4200', '624', '25-30',
#        '4-5', '116', '1450', '45-80', '270', '1040', '740', '290',
#        '20 -  15', '145', '608', '3600', '153', '136', '83', '1019',
#        '10-20', '334', '18-20', '--', '1593', '3-6', '591', '12 -15',
#        '330', '5-7', '7-15', '108', '2000-4000', '4-6', '13-14', '27-33',
#        '11-13', '1090', '899', '410', '79', '34-45', '584', '1929',
#        '140200', '401', '86', '97', '15 - 9 - 9', '12-16', '1067', '440',
#        '204', '340', '728', '87', '2660', '1001', '765', '7500'],
#       dtype=object)

# %%
## correlation matrix with correlations as numbers
n = room_features.shape[1]
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(room_features.corr(), dtype=bool))

corr = df_room_features.corr()
ax = sns.heatmap(
    corr,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
# Out:
# /Users/petermcisaac/neue-fische-traum/traum-preis/.venv/lib/python3.8/site-packages/seaborn/matrix.py:301: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /Users/petermcisaac/neue-fische-traum/traum-preis/.venv/lib/python3.8/site-packages/seaborn/matrix.py:301: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
