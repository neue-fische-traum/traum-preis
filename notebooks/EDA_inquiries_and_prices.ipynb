# %% [markdown]
# # EDA exploring for Inquiry and Prices dataset

# %% [markdown]
# ## Import necassary libraries

# %%
# Import necassary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from scipy import stats

# %%
# %matplotlib inline

# %%
#Load datasets
df_merged_IP = pd.read_csv('../data/merged_inquiries_and_prices.csv')

# %%
df_merged_IP.head()
# Out:
#    Unnamed: 0                            listing_id  title_x  \
# 0           0  b334776d-0cf1-51f1-8cdc-37535b280f3d  Anfrage
# 1           2  80f54c2a-c1f9-5744-a2c8-b8764c0bde87  Anfrage
# 2           3  80f54c2a-c1f9-5744-a2c8-b8764c0bde87  Anfrage
# 3           5  202306bf-f261-5975-8356-11719a53a063  Anfrage
# 4          11  afcd1d75-762c-59e0-b59a-70bd6432cd8d  Anfrage
#
#                   date               time_x  adult_count_x  children_count_x  \
# 0  2019-01-01 00:00:00  2021-07-20 00:07:31            6.0               2.0
# 1  2019-01-01 00:00:00  2021-07-20 00:24:34            2.0               1.0
# 2  2019-01-01 00:00:00  2021-07-20 00:24:34            2.0               1.0
# 3  2019-01-01 00:00:00  2021-07-20 01:06:48            2.0               0.0
# 4  2019-01-01 00:00:00  2021-07-20 03:30:20            2.0               1.0
#
#    pets_count_x       arrival_date_x     departure_date_x  inquiry_price_x  \
# 0           0.0  2019-07-24 00:00:00  2019-07-31 00:00:00           1601.0
# 1           0.0  2019-10-13 00:00:00  2019-10-20 00:00:00              0.0
# 2           0.0  2019-10-13 00:00:00  2019-10-20 00:00:00              0.0
# 3           0.0  2019-04-30 00:00:00  2019-05-03 00:00:00            237.0
# 4           0.0  2019-07-06 00:00:00  2019-07-14 00:00:00            705.0
#
#    length_stay_x  min_days            date_from              date_to  \
# 0              7       7.0  2019-06-14 00:00:00  2019-09-01 00:00:00
# 1              7       2.0  2019-09-27 00:00:00  2019-10-13 00:00:00
# 2              7       2.0  2019-10-13 00:00:00  2019-10-28 00:00:00
# 3              3       3.0  2018-09-30 00:00:00  2019-06-01 00:00:00
# 4              8       3.0  2019-07-06 00:00:00  2019-07-07 00:00:00
#
#    filled_in_price_per_day  filled_in_price_per_week    month price_catagory
# 0                    188.0                    1316.0  2019-06           Both
# 1                     75.0                     500.0  2019-09           Both
# 2                     75.0                     500.0  2019-10           Both
# 3                     79.0                     553.0  2018-09            Day
# 4                    105.0                     735.0  2019-07            Day

# %% [markdown]
# ## Correcting date and time formatting.

# %%
df_merged_IP['date_from'] = pd.to_datetime(df_merged_IP['date_from'], errors = 'coerce')
df_merged_IP['date_to'] = pd.to_datetime(df_merged_IP['date_to'], errors = 'coerce')
df_merged_IP['date'] = pd.to_datetime(df_merged_IP['time_x'], errors = 'coerce')
df_merged_IP['time_x'] = pd.to_datetime(df_merged_IP['date'], errors = 'coerce')
df_merged_IP['arrival_date_x'] = pd.to_datetime(df_merged_IP['arrival_date_x'], errors = 'coerce')
df_merged_IP['departure_date_x'] = pd.to_datetime(df_merged_IP['departure_date_x'], errors = 'coerce')

# %%
# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (11, 7)

# %% [markdown]
# ## Deleting redundant column

# %%
del df_merged_IP['Unnamed: 0']

# %% [markdown]
# ## Descriptive statistics

# %%
df_merged_IP.describe()
# Out:
#        adult_count_x  children_count_x  pets_count_x  inquiry_price_x  \
# count   1.111426e+06      1.111426e+06  1.111426e+06     1.111426e+06
# mean    2.738881e+00      3.173536e-01  1.203832e-01     6.253430e+02
# std     1.120436e+00      6.591467e-01  3.254092e-01     3.746130e+02
# min     0.000000e+00      0.000000e+00  0.000000e+00     0.000000e+00
# 25%     2.000000e+00      0.000000e+00  0.000000e+00     3.440000e+02
# 50%     2.000000e+00      0.000000e+00  0.000000e+00     5.520000e+02
# 75%     4.000000e+00      0.000000e+00  0.000000e+00     8.300000e+02
# max     6.000000e+00      2.000000e+00  1.000000e+00     1.820000e+03
#
#        length_stay_x      min_days  filled_in_price_per_day  \
# count   1.111426e+06  1.111426e+06             1.111426e+06
# mean    6.681006e+00  3.882130e+00             8.562572e+01
# std     3.050047e+00  2.178611e+00             3.449720e+01
# min     1.000000e+00  1.000000e+00             1.000000e-02
# 25%     4.000000e+00  2.000000e+00             6.000000e+01
# 50%     7.000000e+00  4.000000e+00             8.000000e+01
# 75%     7.000000e+00  6.000000e+00             1.008571e+02
# max     1.400000e+01  2.800000e+01             2.200000e+02
#
#        filled_in_price_per_week
# count              1.111426e+06
# mean               5.912741e+02
# std                2.380342e+02
# min                7.000000e-02
# 25%                4.200000e+02
# 50%                5.600000e+02
# 75%                7.000000e+02
# max                1.540000e+03

# %%
df_merged_IP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111426 entries, 0 to 1111425
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   listing_id                1111426 non-null  object
#  1   title_x                   1111426 non-null  object
#  2   date                      1111426 non-null  datetime64[ns]
#  3   time_x                    1111426 non-null  datetime64[ns]
#  4   adult_count_x             1111426 non-null  float64
#  5   children_count_x          1111426 non-null  float64
#  6   pets_count_x              1111426 non-null  float64
#  7   arrival_date_x            1111426 non-null  datetime64[ns]
#  8   departure_date_x          1111426 non-null  datetime64[ns]
#  9   inquiry_price_x           1111426 non-null  float64
#  10  length_stay_x             1111426 non-null  int64
#  11  min_days                  1111426 non-null  float64
#  12  date_from                 1111426 non-null  datetime64[ns]
#  13  date_to                   1111426 non-null  datetime64[ns]
#  14  filled_in_price_per_day   1111426 non-null  float64
#  15  filled_in_price_per_week  1111426 non-null  float64
#  16  month                     1111426 non-null  object
#  17  price_catagory            1111426 non-null  object
# dtypes: datetime64[ns](6), float64(7), int64(1), object(4)
# memory usage: 152.6+ MB

# %% [markdown]
# ## graphing interactions

# %%
# Step 0 - Read the dataset, calculate column correlations and make a seaborn heatmap
corr = df_merged_IP.corr()
ax = sns.heatmap(
    corr,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right')
# Out:
# [Text(0.5, 0, 'adult_count_x'),
#  Text(1.5, 0, 'children_count_x'),
#  Text(2.5, 0, 'pets_count_x'),
#  Text(3.5, 0, 'inquiry_price_x'),
#  Text(4.5, 0, 'length_stay_x'),
#  Text(5.5, 0, 'min_days'),
#  Text(6.5, 0, 'filled_in_price_per_day'),
#  Text(7.5, 0, 'filled_in_price_per_week')]

# %%
df_merged_IP.corr()
# Out:
#                           adult_count_x  children_count_x  pets_count_x  \
# adult_count_x                  1.000000         -0.212923     -0.048524
# children_count_x              -0.212923          1.000000     -0.002416
# pets_count_x                  -0.048524         -0.002416      1.000000
# inquiry_price_x                0.169583          0.077498     -0.028333
# length_stay_x                 -0.046001          0.015210      0.003801
# min_days                      -0.020322          0.026577     -0.018997
# filled_in_price_per_day        0.222691          0.066341     -0.036067
# filled_in_price_per_week       0.223072          0.068312     -0.038293
#
#                           inquiry_price_x  length_stay_x  min_days  \
# adult_count_x                    0.169583      -0.046001 -0.020322
# children_count_x                 0.077498       0.015210  0.026577
# pets_count_x                    -0.028333       0.003801 -0.018997
# inquiry_price_x                  1.000000       0.715489  0.369758
# length_stay_x                    0.715489       1.000000  0.376402
# min_days                         0.369758       0.376402  1.000000
# filled_in_price_per_day          0.616926       0.093331  0.203784
# filled_in_price_per_week         0.627612       0.100052  0.222707
#
#                           filled_in_price_per_day  filled_in_price_per_week
# adult_count_x                            0.222691                  0.223072
# children_count_x                         0.066341                  0.068312
# pets_count_x                            -0.036067                 -0.038293
# inquiry_price_x                          0.616926                  0.627612
# length_stay_x                            0.093331                  0.100052
# min_days                                 0.203784                  0.222707
# filled_in_price_per_day                  1.000000                  0.987181
# filled_in_price_per_week                 0.987181                  1.000000

# %%
plt.scatter(df_merged_IP['inquiry_price_x'], df_merged_IP['filled_in_price_per_day'], c=df_merged_IP['filled_in_price_per_day'], cmap='rainbow');

# %%
df_merged_IP['price_catagory'].unique()
# Out:
# array(['Both', 'Day', 'Week'], dtype=object)

# %%
# Import data from sklearn.datasets
data = df_merged_IP

# Define features and target
X = data.data
y = data.target
target_names = data.target_names

# Convert arrays to dataframe
df_X = pd.DataFrame(X, columns=data.feature_names)
df_y = pd.DataFrame(y, columns=['price_catagory'])
df_y.price_catagory.replace({0: target_names[0], 1: target_names[1], 2: target_names[2]}, inplace=True)
df_merge1 = df_X.join(df_y)
target_names = data.target_names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/f3/z2tpzycd57bfz6359zgkz9f00000gn/T/ipykernel_47967/2206380593.py in <module>
#       3
#       4 # Define features and target
# ----> 5 X = data.data
#       6 y = data.target
#       7 target_names = data.target_names
#
# ~/neuefische-traum/traum-preis/.venv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
sns.pairplot(df_merged_IP, hue="price_catagory", height=3);

# %% [markdown]
# ## Modelling

# %%
smf.ols(formula='inquiry_price_x ~ filled_in_price_per_day + filled_in_price_per_week', data=df_merged_IP).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        inquiry_price_x   R-squared:                       0.394
# Model:                            OLS   Adj. R-squared:                  0.394
# Method:                 Least Squares   F-statistic:                 3.616e+05
# Date:                Wed, 21 Jul 2021   Prob (F-statistic):               0.00
# Time:                        09:46:01   Log-Likelihood:            -7.8847e+06
# No. Observations:             1111426   AIC:                         1.577e+07
# Df Residuals:                 1111423   BIC:                         1.577e+07
# Df Model:                           2
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   42.4919      0.742     57.235      0.000      41.037      43.947
# filled_in_price_per_day     -1.1257      0.050    -22.410      0.000      -1.224      -1.027
# filled_in_price_per_week     1.1488      0.007    157.801      0.000       1.135       1.163
# ==============================================================================
# Omnibus:                    93213.594   Durbin-Watson:                   1.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           202275.113
# Skew:                           0.544   Prob(JB):                         0.00
# Kurtosis:                       4.785   Cond. No.                     1.73e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.73e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
